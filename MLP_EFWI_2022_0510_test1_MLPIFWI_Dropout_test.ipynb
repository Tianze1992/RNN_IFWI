# %%
import sys
import torch
torch.cuda.empty_cache()
import torch.nn as nn
print(sys.version)
print("----------------")
print("torch.cuda.is_available: ",torch.cuda.is_available())
import scipy.io as spio
from Plotting_class import add_colorbar
from Plotting_class import imagesc
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
import math

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# 3.9.12 (main, Apr  4 2022, 05:22:27) [MSC v.1916 64 bit (AMD64)]
# ----------------
# torch.cuda.is_available:  True

# %% [markdown]
# # Demo code for the implicit full waveform inversion (IFWI)

# %% [markdown]
# ## The basic methodology of the IFWI:
# ### Instead of directly updating the elastic models, we define the neural network (NN), which generates the elastic models, and optimize the weights in NN.
#
# <img src="IFWI_fig.PNG" width="50%">
#
# ### Major advantage:
# ##### IFWI reduce the dependence on the explicit accurate initial models like in the conventional FWI. The initial model for IFWI is randomly generated according to prior information.
#
#
# ### Refereneces:
# ##### (1) "Implicit Seismic Full Waveform Inversion With Deep Neural Representation", Jian Sun, Kristopher Innanen, Tianze Zhang, and Daniel Trad, Journal of Geophysical Research: Solid Earth, e2022JB025964
#
# ##### (2) "Multilayer Perceptron and Bayesian Neural Network-Based Elastic Implicit Full Waveform Inversion", T. Zhang, J. Sun, D. Trad and K. Innanen, IEEE Transactions on Geoscience and Remote Sensing, vol. 61, pp. 1-16, 2023

# %% [markdown]
# # Step 1: Observed data generating

# %%
# importing the true models for vp, vs and denisty, which are part of the Marmousi model
vp0 = spio.loadmat('./Mar_ori_vp.mat', squeeze_me=True)
vp0_true = vp0['data_vp']
vp0_true = torch.from_numpy(np.array(vp0_true, dtype=np.float64))
vp0_true = torch.as_tensor(vp0_true)
[nz, nx] = [vp0_true.shape[0],vp0_true.shape[1]]

sparse_x = 8
sparse_z = 30

nnz = np.arange(0,nz,sparse_x).tolist()
nnx = np.arange(0,nx,sparse_z).tolist()
vp0_true = vp0_true[nnz,:]; vp0_true=vp0_true[:,nnx]
[nz, nx] = [vp0_true.shape[0],vp0_true.shape[1]]

c1 =50; c2=130;
c3 =1;  c4=200;
vs0 = spio.loadmat('./Mar_ori_vs.mat', squeeze_me=True)
vs0_true = vs0['data_vs']
vs0_true = torch.from_numpy(np.array(vs0_true, dtype=np.float64))
vs0_true = torch.as_tensor(vs0_true)
[nz, nx] = [vs0_true.shape[0],vs0_true.shape[1]]


vs0_true = vs0_true[nnz,:]; vs0_true=vs0_true[:,nnx]
[nz, nx] = [vs0_true.shape[0],vs0_true.shape[1]]

vs0_true = vs0_true[c1:c2,c3:c4]
vs_tensor = vs0_true+1500

rho0 = spio.loadmat('./Mar_ori_rho.mat', squeeze_me=True)
rho0_true = rho0['data_rho']
rho0_true = torch.from_numpy(np.array(rho0_true, dtype=np.float64))
rho0_true = torch.as_tensor(rho0_true)
[nz, nx] = [rho0_true.shape[0],rho0_true.shape[1]]

nnz = np.arange(0,nz,sparse_x).tolist()
nnx = np.arange(0,nx,sparse_z).tolist()
rho0_true = rho0_true[nnz,:]; rho0_true=rho0_true[:,nnx]
[nz, nx] = [rho0_true.shape[0],rho0_true.shape[1]]

rho0_true = rho0_true[c1:c2,c3:c4]
rho_tensor = rho0_true*1000


dx0=20
dz0=20


vp0_true = vp0_true[c1:c2,c3:c4]
vp_tensor = vp0_true+1400

# %%
[nz, nx] = [vp_tensor.shape[0],vp_tensor.shape[1]]

dx0 =20
dz0 =20

# %%
font_size = 16
color_bar = 'bwr'



fig = plt.figure(figsize=(20, 10))
gs = fig.add_gridspec(1, 3)
ax = fig.add_subplot(gs[0, 0])
im = ax.imshow(vp_tensor.cpu().squeeze(), extent=[0, nx*dx0/1000, nz*dz0/1000, 0], aspect=1, cmap=color_bar)
cbar = add_colorbar(ax, im, ax.transAxes, width="3%", ctitle='$km/s$')
ax.set_title(r"True Vp", fontsize=font_size)
ax.set_xlabel("Distance (km)", fontsize=font_size)
ax.set_ylabel("Depth (km)", fontsize=font_size)

ax = fig.add_subplot(gs[0, 1])
im = ax.imshow(vs_tensor.cpu().squeeze(), extent=[0, nx*dx0/1000, nz*dz0/1000, 0], aspect=1, cmap=color_bar)
cbar = add_colorbar(ax, im, ax.transAxes, width="3%", ctitle='$km/s$')
ax.set_title(r"True Vs", fontsize=font_size)
ax.set_xlabel("Distance (km)", fontsize=font_size)
ax.set_yticks([])

ax = fig.add_subplot(gs[0, 2])
im = ax.imshow(rho_tensor.cpu().squeeze(), extent=[0, nx*dx0/1000, nz*dz0/1000, 0], aspect=1, cmap=color_bar)
cbar = add_colorbar(ax, im, ax.transAxes, width="3%", ctitle='$kg/m^{3}$')
ax.set_title(r"True $\rho$", fontsize=font_size)
ax.set_xlabel("Distance (km)", fontsize=font_size)
ax.set_yticks([])
#ax.set_ylabel("Depth (km)", fontsize=font_size)

plt.subplots_adjust(left=0.125,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.2, 
                    hspace=0.4)

# %%
#importing the forward modeling engine, RNN-based method, defining the acquisition system, and genertate the observed data
from rnn_fd_elastic2 import rnn2D
from generator import wGenerator
sample_interval = 30
freeSurface = False                                                    # free surface option for forward modeling
npad = 10                                                              # velocity padding in grid points
freq = 5.0                                                             # dominant frequency of wavelet in Hz
dt = 0.002                                                             # time samling interval, fixed for all shots gathers
nt = 1000                                                              # number of samples in time

#defining the sources locations on the computational grid
xs = np.arange(2,nx,30,dtype=np.int32) # source x-coordinate
zs = np.ones(xs.shape, dtype=np.int32) # source z-coordinate
#defining the receivors locations on the computational grid
xr = np.arange(0,nx, 1, dtype=np.int32) # receiver x-coordinate
zr = np.ones(xr.shape, dtype=np.int32) # receiver z-coordinate


#defining the sources wave let
t = dt * torch.arange(0, nt, dtype=torch.float32)                                # create time vector
wavelet = wGenerator(t, freq).ricker().to(device)*10000000                       # generate wavelet


#defining the grid length of the computational grid
dx = 20
dz = 20


#send tensor to gpu device, for GPU acceleration 
vp_tensor = torch.reshape(vp_tensor,(1,nz,nx)).type(dtype=torch.float32).to(device)
vs_tensor = torch.reshape(vs_tensor,(1,nz,nx)).type(dtype=torch.float32).to(device)
rho_tensor = torch.reshape(rho_tensor,(1,nz,nx)).type(dtype=torch.float32).to(device)

# define the object according to the rnn2D class
forward_rnn = rnn2D(nz, nx, zs, xs, zr, xr, dz, dt, 
                    npad=npad, order=2, vmax=vp_tensor.max(), 
                    freeSurface=True, 
                    dtype=torch.float32, 
                    device=device).to(device)

# Using this object to perfrom the forward modeling obtaining the observed data
vx_save, vz_save, \
txx_save, tzz_save, txz_save, \
segment_ytPred_x,segment_ytPred_z,avg_regularizer,\
vp_tensor_out,vs_tensor_out,rho_tensor_out = \
forward_rnn(vp_tensor=vp_tensor.to(device),\
            vs_tensor=vs_tensor.to(device),\
            rho_tensor=rho_tensor.to(device),\
            segment_wavelet=wavelet)

shots= torch.cat((segment_ytPred_x.reshape(1, len(xs),len(t), len(xr)),\
                  segment_ytPred_z.reshape(1, len(xs),len(t), len(xr))),dim=0)
print(shots.shape)
# Out:
# torch.Size([2, 7, 1000, 199])

# %%
fig=plt.figure(figsize=(30, 10))
imagesc(fig,
        segment_ytPred_z.cpu().numpy().reshape(-1, int(len(xs)), len(t), len(xr)),
        vmin=-segment_ytPred_z.max()/100,
        vmax=segment_ytPred_z.max()/100,
        extent=[0, nx*dz/1000, t.numpy().max(), 0],
        aspect=3, #5
        nRows_nCols=(1,len(xs)),
        cmap='gray',
        ylabel="Time (s)",
        xlabel="Position (km)",
        clabel="",
        xticks=np.arange(0., int(nx*dz/1000), 2),
        yticks=np.arange(0., t.numpy().max(), 1.),
        fontsize=15,
        cbar_width="7%",
        cbar_height="100%",
        cbar_loc='lower left')
#fig.tight_layout(pad=-.05)

# %%
fig=plt.figure(figsize=(30, 10))
imagesc(fig,
        segment_ytPred_x.cpu().numpy().reshape(-1, int(len(xs)), len(t), len(xr)),
        vmin=-segment_ytPred_z.max()/50,
        vmax=segment_ytPred_z.max()/50,
        extent=[0, nx*dz/1000, t.numpy().max(), 0],
        aspect=3, #5
        nRows_nCols=(1,len(xs)),
        cmap='gray',
        ylabel="Time (s)",
        xlabel="Position (km)",
        clabel="",
        xticks=np.arange(0., int(nx*dz/1000), 2),
        yticks=np.arange(0., t.numpy().max(), 1.),
        fontsize=15,
        cbar_width="7%",
        cbar_height="100%",
        cbar_loc='lower left')
#fig.tight_layout(pad=-.05)

# %% [markdown]
# # Step two: IFWI

# %%
# obtaining the well log information for the vp, vs, and density , i.e., the mean and the std for each parameter
well_index = 55
std_scale = 1
vp_well = vp_tensor[:,:,well_index]
vs_well = vs_tensor[:,:,well_index]
rho_well = rho_tensor[:,:,well_index]

# %%
from MLP_based_IFWI_2 import IFWI2D
"""
Args:
    segment_size            (int)        ---- the total discrete  number of t
    mean1,                  (float32)    ---- vp mean obtained from well log                         
    std1,                   (float32)    ---- vp std obtained from well log     
    mean2,                  (float32)    ---- vs mean obtained from well log
    std2,                   (float32)    ---- vs std obtained from well log
    mean3,                  (float32)    ---- rho mean obtained from well log
    std3,                   (float32)    ---- rho std obtained from well log
    std_scale,              (float32)    ---- scaling the std in case of the well log does not well represent the target area
    neuron,                 (list of int)---- defining the number of neurons of each NN later
    omega_0,                (float32)    ---- influencing the initialization of the weights        
    activation,             (string)     ---- defining the activation functions of the neural network
    bias,                   (Boolean)    ---- if bias is included in the neural network
    outermost_linear,       (Boolean)    ---- if True, then not activation function is applied on the last layer.
    ns,                     (float32)    ---- total number of the shots
    nz,                     (float32)    ---- total number of the grid points in z direction 
    nx,                     (float32)    ---- total number of the grid points in x direction 
    zs,                     (float32)    ---- shots positions in the z direction on the computational grid
    xs,                     (float32)    ---- shots positions in the x direction on the computational grid
    zr,                     (float32)    ---- receiver positions in the z direction on the computational grid
    xr,                     (float32)    ---- receiver positions in the x direction on the computational grid
    dz,                     (float32)    ---- receiver positions in the z direction on the computational grid
    dt,                     (float32)    ---- receiver positions in the x direction on the computational grid
    nt,                     (float32)    ---- the total discrete  number of t
    npad,                   (int)        ---- number of the PML absorbing layers
    order,                  (int)        ---- order of spatial finite difference
    vmax,                   (float32)    ---- the maximum value of the vs velocity for stable condiction calculation 
    vpadding,               (Boolean)    ---- if the elastic model needs to be padded
    freeSurface,            (Boolean)    ---- if we need the freeSurface modeling condition
    dtype,                  (dtype)      ---- the default datatype
    device,                 (device)     ---- CPU or GPU
"""
model = IFWI2D( segment_size=len(t),
                mean1=((vp_well/1000).mean()), 
                std1 =((vp_well/1000).std()),
                mean2=((vs_well/1000).mean()), 
                std2 =((vs_well/1000).std()),
                mean3=((rho_well/1000).mean()), 
                std3 =((rho_well/1000).std()),
                std_scale = std_scale,
                neuron=[2, 256, 512, 512, 256, 256], 
                omega_0=30, 
                activation='sine', 
                bias=True, 
                outermost_linear=True,
                ns = len(xs), 
                nz=nz,
                nx=nx,
                zs=zs,
                xs=xs,
                zr=zr, 
                xr=xr,
                dz=dz,
                dt=dt,
                nt=nt,
                npad=npad, 
                order=2, 
                vmax=4700,
                vpadding=None,
                freeSurface=True,
                dtype=torch.float32,
                device=device)

train_loss_history  = model.train(MaxIter=500, wavelet=wavelet, shots=shots, option=0, log_interval=1,resume_file_name=None)
# Out:
# this is the the npad 10
# Epoch:     0, Loss: 7.7752e+02
# Epoch:     1, Loss: 7.0592e+02
# Epoch:     2, Loss: 6.6541e+02
# Epoch:     3, Loss: 6.3832e+02
# Epoch:     4, Loss: 6.1460e+02
# Epoch:     5, Loss: 5.8636e+02
# Epoch:     6, Loss: 5.5620e+02
# Epoch:     7, Loss: 5.2526e+02
# Epoch:     8, Loss: 4.9233e+02
# Epoch:     9, Loss: 4.5833e+02
# Epoch:    10, Loss: 4.2262e+02
# Epoch:    11, Loss: 3.8560e+02
# Epoch:    12, Loss: 3.4876e+02
# Epoch:    13, Loss: 3.1481e+02
# Epoch:    14, Loss: 2.8649e+02
# Epoch:    15, Loss: 2.6298e+02
# Epoch:    16, Loss: 2.6718e+02
# Epoch:    17, Loss: 2.2935e+02
# Epoch:    18, Loss: 2.3596e+02
# Epoch:    19, Loss: 2.1070e+02
# Epoch:    20, Loss: 2.1477e+02
# Epoch:    21, Loss: 2.0230e+02
# Epoch:    22, Loss: 1.8672e+02
# Epoch:    23, Loss: 1.9313e+02
# Epoch:    24, Loss: 1.7600e+02
# Epoch:    25, Loss: 1.7432e+02
# Epoch:    26, Loss: 1.6661e+02
# Epoch:    27, Loss: 1.6399e+02
# Epoch:    28, Loss: 1.6182e+02
# Epoch:    29, Loss: 1.5141e+02
# Epoch:    30, Loss: 1.5131e+02
# Epoch:    31, Loss: 1.4489e+02
# Epoch:    32, Loss: 1.4242e+02
# Epoch:    33, Loss: 1.4737e+02
# Epoch:    34, Loss: 1.4368e+02
# Epoch:    35, Loss: 1.2971e+02
# Epoch:    36, Loss: 1.4310e+02
# Epoch:    37, Loss: 1.3632e+02
# Epoch:    38, Loss: 1.2704e+02
# Epoch:    39, Loss: 1.2822e+02
# Epoch:    40, Loss: 1.2880e+02
# Epoch:    41, Loss: 1.2050e+02
# Epoch:    42, Loss: 1.3234e+02
# Epoch:    43, Loss: 1.1892e+02
# Epoch:    44, Loss: 1.3309e+02
# Epoch:    45, Loss: 1.1943e+02
# Epoch:    46, Loss: 1.2608e+02
# Epoch:    47, Loss: 1.1530e+02
# Epoch:    48, Loss: 1.3495e+02
# Epoch:    49, Loss: 1.1923e+02
# Epoch:    50, Loss: 1.1776e+02
# Epoch:    51, Loss: 1.1746e+02
# Epoch:    52, Loss: 1.1235e+02
# Epoch:    53, Loss: 1.0705e+02
# Epoch:    54, Loss: 1.0596e+02
# Epoch:    55, Loss: 1.0794e+02
# Epoch:    56, Loss: 9.9757e+01
# Epoch:    57, Loss: 1.0575e+02
# Epoch:    58, Loss: 1.0314e+02
# Epoch:    59, Loss: 1.0206e+02
# Epoch:    60, Loss: 1.0072e+02
# Epoch:    61, Loss: 9.7584e+01
# Epoch:    62, Loss: 9.9459e+01
# Epoch:    63, Loss: 9.9266e+01
# Epoch:    64, Loss: 9.2035e+01
# Epoch:    65, Loss: 1.0440e+02
# Epoch:    66, Loss: 9.3646e+01
# Epoch:    67, Loss: 9.6351e+01
# Epoch:    68, Loss: 9.0748e+01
# Epoch:    69, Loss: 9.2963e+01
# Epoch:    70, Loss: 8.9631e+01
# Epoch:    71, Loss: 8.9918e+01
# Epoch:    72, Loss: 8.7501e+01
# Epoch:    73, Loss: 8.5976e+01
# Epoch:    74, Loss: 8.6347e+01
# Epoch:    75, Loss: 8.2837e+01
# Epoch:    76, Loss: 8.0446e+01
# Epoch:    77, Loss: 8.3806e+01
# Epoch:    78, Loss: 8.0028e+01
# Epoch:    79, Loss: 7.9239e+01
# Epoch:    80, Loss: 7.9110e+01
# Epoch:    81, Loss: 7.9877e+01
# Epoch:    82, Loss: 7.7318e+01
# Epoch:    83, Loss: 7.5322e+01
# Epoch:    84, Loss: 7.6795e+01
# Epoch:    85, Loss: 7.7846e+01
# Epoch:    86, Loss: 7.3670e+01
# Epoch:    87, Loss: 7.1733e+01
# Epoch:    88, Loss: 7.2312e+01
# Epoch:    89, Loss: 7.0273e+01
# Epoch:    90, Loss: 7.1379e+01
# Epoch:    91, Loss: 7.1219e+01
# Epoch:    92, Loss: 7.1413e+01
# Epoch:    93, Loss: 6.8473e+01
# Epoch:    94, Loss: 6.9434e+01
# Epoch:    95, Loss: 6.9200e+01
# Epoch:    96, Loss: 6.7390e+01
# Epoch:    97, Loss: 6.5842e+01
# Epoch:    98, Loss: 6.7217e+01
# Epoch:    99, Loss: 6.5751e+01
# Epoch:   100, Loss: 6.6119e+01
# Epoch:   101, Loss: 6.4579e+01
# Epoch:   102, Loss: 6.6512e+01
# Epoch:   103, Loss: 6.3829e+01
# Epoch:   104, Loss: 6.3804e+01
# Epoch:   105, Loss: 6.3328e+01
# Epoch:   106, Loss: 6.3549e+01
# Epoch:   107, Loss: 6.1132e+01
# Epoch:   108, Loss: 6.3853e+01
# Epoch:   109, Loss: 6.2724e+01
# Epoch:   110, Loss: 5.9985e+01
# Epoch:   111, Loss: 6.1598e+01
# Epoch:   112, Loss: 6.0425e+01
# Epoch:   113, Loss: 6.2541e+01
# Epoch:   114, Loss: 5.9470e+01
# Epoch:   115, Loss: 5.8342e+01
# Epoch:   116, Loss: 6.0858e+01
# Epoch:   117, Loss: 5.9371e+01
# Epoch:   118, Loss: 5.8856e+01
# Epoch:   119, Loss: 6.0604e+01
# Epoch:   120, Loss: 5.6930e+01
# Epoch:   121, Loss: 5.9652e+01
# Epoch:   122, Loss: 5.8080e+01
# Epoch:   123, Loss: 5.5823e+01
# Epoch:   124, Loss: 5.4649e+01
# Epoch:   125, Loss: 5.4738e+01
# Epoch:   126, Loss: 6.0509e+01
# Epoch:   127, Loss: 5.4013e+01
# Epoch:   128, Loss: 5.5645e+01
# Epoch:   129, Loss: 5.6764e+01
# Epoch:   130, Loss: 5.4196e+01
# Epoch:   131, Loss: 5.3100e+01
# Epoch:   132, Loss: 5.5446e+01
# Epoch:   133, Loss: 5.1826e+01
# Epoch:   134, Loss: 5.7917e+01
# Epoch:   135, Loss: 5.2710e+01
# Epoch:   136, Loss: 5.2254e+01
# Epoch:   137, Loss: 5.1780e+01
# Epoch:   138, Loss: 5.1217e+01
# Epoch:   139, Loss: 5.5227e+01
# Epoch:   140, Loss: 5.2408e+01
# Epoch:   141, Loss: 5.1931e+01
# Epoch:   142, Loss: 5.0126e+01
# Epoch:   143, Loss: 5.1258e+01
# Epoch:   144, Loss: 4.9699e+01
# Epoch:   145, Loss: 5.1158e+01
# Epoch:   146, Loss: 5.0453e+01
# Epoch:   147, Loss: 4.9212e+01
# Epoch:   148, Loss: 4.9788e+01
# Epoch:   149, Loss: 5.2234e+01
# Epoch:   150, Loss: 4.6810e+01
# Epoch:   151, Loss: 4.8717e+01
# Epoch:   152, Loss: 4.8867e+01
# Epoch:   153, Loss: 4.7855e+01
# Epoch:   154, Loss: 4.8434e+01
# Epoch:   155, Loss: 4.8918e+01
# Epoch:   156, Loss: 4.8099e+01
# Epoch:   157, Loss: 4.9163e+01
# Epoch:   158, Loss: 4.7963e+01
# Epoch:   159, Loss: 4.7455e+01
# Epoch:   160, Loss: 4.6920e+01
# Epoch:   161, Loss: 4.6655e+01
# Epoch:   162, Loss: 4.6758e+01
# Epoch:   163, Loss: 4.5711e+01
# Epoch:   164, Loss: 4.5797e+01
# Epoch:   165, Loss: 4.7998e+01
# Epoch:   166, Loss: 4.6150e+01
# Epoch:   167, Loss: 4.8584e+01
# Epoch:   168, Loss: 4.5808e+01
# Epoch:   169, Loss: 4.7231e+01
# Epoch:   170, Loss: 4.6890e+01
# Epoch:   171, Loss: 4.5768e+01
# Epoch:   172, Loss: 4.6432e+01
# Epoch:   173, Loss: 4.3896e+01
# Epoch:   174, Loss: 4.6817e+01
# Epoch:   175, Loss: 4.2260e+01
# Epoch:   176, Loss: 4.3349e+01
# Epoch:   177, Loss: 4.5368e+01
# Epoch:   178, Loss: 4.2870e+01
# Epoch:   179, Loss: 4.4520e+01
# Epoch:   180, Loss: 4.1988e+01
# Epoch:   181, Loss: 4.3084e+01
# Epoch:   182, Loss: 4.3644e+01
# Epoch:   183, Loss: 4.3444e+01
# Epoch:   184, Loss: 4.4454e+01
# Epoch:   185, Loss: 4.3441e+01
# Epoch:   186, Loss: 4.3090e+01
# Epoch:   187, Loss: 4.2858e+01
# Epoch:   188, Loss: 4.3577e+01
# Epoch:   189, Loss: 4.0527e+01
# Epoch:   190, Loss: 4.3058e+01
# Epoch:   191, Loss: 4.2453e+01
# Epoch:   192, Loss: 4.1106e+01
# Epoch:   193, Loss: 4.2432e+01
# Epoch:   194, Loss: 4.2227e+01
# Epoch:   195, Loss: 4.1363e+01
# Epoch:   196, Loss: 4.2238e+01
# Epoch:   197, Loss: 4.0129e+01
# Epoch:   198, Loss: 4.1589e+01
# Epoch:   199, Loss: 3.9057e+01
# Epoch:   200, Loss: 4.1462e+01
# Epoch:   201, Loss: 4.0491e+01
# Epoch:   202, Loss: 4.0431e+01
# Epoch:   203, Loss: 4.1873e+01
# Epoch:   204, Loss: 3.8995e+01
# Epoch:   205, Loss: 3.9604e+01
# Epoch:   206, Loss: 3.9773e+01
# Epoch:   207, Loss: 4.0309e+01
# Epoch:   208, Loss: 3.9033e+01
# Epoch:   209, Loss: 3.9930e+01
# Epoch:   210, Loss: 4.0039e+01
# Epoch:   211, Loss: 3.8685e+01
# Epoch:   212, Loss: 3.9427e+01
# Epoch:   213, Loss: 4.0186e+01
# Epoch:   214, Loss: 3.8957e+01
# Epoch:   215, Loss: 4.0067e+01
# Epoch:   216, Loss: 3.9878e+01
# Epoch:   217, Loss: 3.8008e+01
# Epoch:   218, Loss: 4.0121e+01
# Epoch:   219, Loss: 3.7529e+01
# Epoch:   220, Loss: 3.9894e+01
# Epoch:   221, Loss: 3.8737e+01
# Epoch:   222, Loss: 3.8551e+01
# Epoch:   223, Loss: 3.7844e+01
# Epoch:   224, Loss: 3.9520e+01
# Epoch:   225, Loss: 3.7370e+01
# Epoch:   226, Loss: 3.8091e+01
# Epoch:   227, Loss: 3.8536e+01
# Epoch:   228, Loss: 3.6359e+01
# Epoch:   229, Loss: 3.7809e+01
# Epoch:   230, Loss: 3.7191e+01
# Epoch:   231, Loss: 3.8097e+01
# Epoch:   232, Loss: 3.6282e+01
# Epoch:   233, Loss: 3.9049e+01
# Epoch:   234, Loss: 3.7136e+01
# Epoch:   235, Loss: 3.7522e+01
# Epoch:   236, Loss: 3.6215e+01
# Epoch:   237, Loss: 3.7955e+01
# Epoch:   238, Loss: 3.5500e+01
# Epoch:   239, Loss: 3.8648e+01
# Epoch:   240, Loss: 3.3958e+01
# Epoch:   241, Loss: 3.7163e+01
# Epoch:   242, Loss: 3.5759e+01
# Epoch:   243, Loss: 3.6732e+01
# Epoch:   244, Loss: 3.5826e+01
# Epoch:   245, Loss: 3.5616e+01
# Epoch:   246, Loss: 3.6636e+01
# Epoch:   247, Loss: 3.7235e+01
# Epoch:   248, Loss: 3.5635e+01
# Epoch:   249, Loss: 3.5867e+01
# Epoch:   250, Loss: 3.5487e+01
# Epoch:   251, Loss: 3.5424e+01
# Epoch:   252, Loss: 3.4656e+01
# Epoch:   253, Loss: 3.4964e+01
# Epoch:   254, Loss: 3.5717e+01
# Epoch:   255, Loss: 3.4499e+01
# Epoch:   256, Loss: 3.4656e+01
# Epoch:   257, Loss: 3.3914e+01
# Epoch:   258, Loss: 3.4999e+01
# Epoch:   259, Loss: 3.4097e+01
# Epoch:   260, Loss: 3.6761e+01
# Epoch:   261, Loss: 3.4367e+01
# Epoch:   262, Loss: 3.4123e+01
# Epoch:   263, Loss: 3.6472e+01
# Epoch:   264, Loss: 3.3890e+01
# Epoch:   265, Loss: 3.5745e+01
# Epoch:   266, Loss: 3.3123e+01
# Epoch:   267, Loss: 3.6023e+01
# Epoch:   268, Loss: 3.2557e+01
# Epoch:   269, Loss: 3.4467e+01
# Epoch:   270, Loss: 3.4788e+01
# Epoch:   271, Loss: 3.3796e+01
# Epoch:   272, Loss: 3.3416e+01
# Epoch:   273, Loss: 3.5526e+01
# Epoch:   274, Loss: 3.3525e+01
# Epoch:   275, Loss: 3.5153e+01
# Epoch:   276, Loss: 3.2382e+01
# Epoch:   277, Loss: 3.5047e+01
# Epoch:   278, Loss: 3.3208e+01
# Epoch:   279, Loss: 3.3275e+01
# Epoch:   280, Loss: 3.2949e+01
# Epoch:   281, Loss: 3.4150e+01
# Epoch:   282, Loss: 3.0439e+01
# Epoch:   283, Loss: 3.4994e+01
# Epoch:   284, Loss: 3.3144e+01
# Epoch:   285, Loss: 3.4619e+01
# Epoch:   286, Loss: 3.4835e+01
# Epoch:   287, Loss: 3.3715e+01
# Epoch:   288, Loss: 3.4153e+01
# Epoch:   289, Loss: 3.3499e+01
# Epoch:   290, Loss: 3.2896e+01
# Epoch:   291, Loss: 3.3862e+01
# Epoch:   292, Loss: 3.2967e+01
# Epoch:   293, Loss: 3.3656e+01
# Epoch:   294, Loss: 3.3192e+01
# Epoch:   295, Loss: 3.2786e+01
# Epoch:   296, Loss: 3.3649e+01
# Epoch:   297, Loss: 3.2008e+01
# Epoch:   298, Loss: 3.2393e+01
# Epoch:   299, Loss: 3.3457e+01
# Epoch:   300, Loss: 3.0826e+01
# Epoch:   301, Loss: 3.2997e+01
# Epoch:   302, Loss: 3.2472e+01
# Epoch:   303, Loss: 3.1656e+01
# Epoch:   304, Loss: 3.2273e+01
# Epoch:   305, Loss: 3.2868e+01
# Epoch:   306, Loss: 3.1103e+01
# Epoch:   307, Loss: 3.3894e+01
# Epoch:   308, Loss: 3.0378e+01
# Epoch:   309, Loss: 3.2552e+01
# Epoch:   310, Loss: 3.1554e+01
# Epoch:   311, Loss: 3.0812e+01
# Epoch:   312, Loss: 3.1038e+01
# Epoch:   313, Loss: 3.1424e+01
# Epoch:   314, Loss: 3.1090e+01
# Epoch:   315, Loss: 3.1547e+01
# Epoch:   316, Loss: 3.0519e+01
# Epoch:   317, Loss: 3.1626e+01
# Epoch:   318, Loss: 3.3600e+01
# Epoch:   319, Loss: 3.0710e+01
# Epoch:   320, Loss: 3.1037e+01
# Epoch:   321, Loss: 3.1454e+01
# Epoch:   322, Loss: 3.0107e+01
# Epoch:   323, Loss: 3.2257e+01
# Epoch:   324, Loss: 2.9321e+01
# Epoch:   325, Loss: 3.1537e+01
# Epoch:   326, Loss: 3.0165e+01
# Epoch:   327, Loss: 3.1946e+01
# Epoch:   328, Loss: 3.0763e+01
# Epoch:   329, Loss: 3.1298e+01
# Epoch:   330, Loss: 3.0942e+01
# Epoch:   331, Loss: 2.9667e+01
# Epoch:   332, Loss: 3.0732e+01
# Epoch:   333, Loss: 3.0648e+01
# Epoch:   334, Loss: 2.9787e+01
# Epoch:   335, Loss: 3.1808e+01
# Epoch:   336, Loss: 2.9879e+01
# Epoch:   337, Loss: 3.0125e+01
# Epoch:   338, Loss: 2.8578e+01
# Epoch:   339, Loss: 3.1442e+01
# Epoch:   340, Loss: 2.8495e+01
# Epoch:   341, Loss: 3.2142e+01
# Epoch:   342, Loss: 2.8600e+01
# Epoch:   343, Loss: 3.0379e+01
# Epoch:   344, Loss: 2.9757e+01
# Epoch:   345, Loss: 3.0382e+01
# Epoch:   346, Loss: 2.9520e+01
# Epoch:   347, Loss: 2.9799e+01
# Epoch:   348, Loss: 2.8901e+01
# Epoch:   349, Loss: 2.9334e+01
# Epoch:   350, Loss: 3.1736e+01
# Epoch:   351, Loss: 2.8094e+01
# Epoch:   352, Loss: 3.2179e+01
# Epoch:   353, Loss: 2.8920e+01
# Epoch:   354, Loss: 2.9869e+01
# Epoch:   355, Loss: 3.0789e+01
# Epoch:   356, Loss: 2.8476e+01
# Epoch:   357, Loss: 2.8338e+01
# Epoch:   358, Loss: 3.0353e+01
# Epoch:   359, Loss: 2.7771e+01
# Epoch:   360, Loss: 2.9633e+01
# Epoch:   361, Loss: 2.8677e+01
# Epoch:   362, Loss: 2.9823e+01
# Epoch:   363, Loss: 2.8375e+01
# Epoch:   364, Loss: 2.8897e+01
# Epoch:   365, Loss: 2.8421e+01
# Epoch:   366, Loss: 3.0299e+01
# Epoch:   367, Loss: 2.7542e+01
# Epoch:   368, Loss: 3.0632e+01
# Epoch:   369, Loss: 2.7806e+01
# Epoch:   370, Loss: 2.8368e+01
# Epoch:   371, Loss: 2.8731e+01
# Epoch:   372, Loss: 2.8024e+01
# Epoch:   373, Loss: 3.0035e+01
# Epoch:   374, Loss: 2.8654e+01
# Epoch:   375, Loss: 2.9218e+01
# Epoch:   376, Loss: 2.8276e+01
# Epoch:   377, Loss: 2.8931e+01
# Epoch:   378, Loss: 2.8716e+01
# Epoch:   379, Loss: 2.8074e+01
# Epoch:   380, Loss: 2.8665e+01
# Epoch:   381, Loss: 2.8504e+01
# Epoch:   382, Loss: 2.8499e+01
# Epoch:   383, Loss: 2.7551e+01
# Epoch:   384, Loss: 2.9897e+01
# Epoch:   385, Loss: 2.7019e+01
# Epoch:   386, Loss: 2.9977e+01
# Epoch:   387, Loss: 2.7538e+01
# Epoch:   388, Loss: 2.8830e+01
# Epoch:   389, Loss: 2.8387e+01
# Epoch:   390, Loss: 2.7391e+01
# Epoch:   391, Loss: 2.9494e+01
# Epoch:   392, Loss: 2.6636e+01
# Epoch:   393, Loss: 2.8354e+01
# Epoch:   394, Loss: 2.8995e+01
# Epoch:   395, Loss: 2.7287e+01
# Epoch:   396, Loss: 2.6759e+01
# Epoch:   397, Loss: 2.9080e+01
# Epoch:   398, Loss: 2.7101e+01
# Epoch:   399, Loss: 2.7793e+01
# Epoch:   400, Loss: 2.6786e+01
# Epoch:   401, Loss: 2.7239e+01
# Epoch:   402, Loss: 2.6934e+01
# Epoch:   403, Loss: 2.7965e+01
# Epoch:   404, Loss: 2.6767e+01
# Epoch:   405, Loss: 2.8320e+01
# Epoch:   406, Loss: 2.6122e+01
# Epoch:   407, Loss: 2.8789e+01
# Epoch:   408, Loss: 2.6382e+01
# Epoch:   409, Loss: 2.5930e+01
# Epoch:   410, Loss: 2.7385e+01
# Epoch:   411, Loss: 2.7832e+01
# Epoch:   412, Loss: 2.7788e+01
# Epoch:   413, Loss: 2.6937e+01
# Epoch:   414, Loss: 2.7466e+01
# Epoch:   415, Loss: 2.7211e+01
# Epoch:   416, Loss: 2.6139e+01
# Epoch:   417, Loss: 2.7212e+01
# Epoch:   418, Loss: 2.6394e+01
# Epoch:   419, Loss: 2.7300e+01
# Epoch:   420, Loss: 2.7419e+01
# Epoch:   421, Loss: 2.7527e+01
# Epoch:   422, Loss: 2.8027e+01
# Epoch:   423, Loss: 2.7709e+01
# Epoch:   424, Loss: 2.7051e+01
# Epoch:   425, Loss: 2.6302e+01
# Epoch:   426, Loss: 2.7038e+01
# Epoch:   427, Loss: 2.7199e+01
# Epoch:   428, Loss: 2.7195e+01
# Epoch:   429, Loss: 2.6317e+01
# Epoch:   430, Loss: 2.8070e+01
# Epoch:   431, Loss: 2.5517e+01
# Epoch:   432, Loss: 2.6986e+01
# Epoch:   433, Loss: 2.5403e+01
# Epoch:   434, Loss: 2.7962e+01
# Epoch:   435, Loss: 2.6205e+01
# Epoch:   436, Loss: 2.6859e+01
# Epoch:   437, Loss: 2.4949e+01
# Epoch:   438, Loss: 2.7001e+01
# Epoch:   439, Loss: 2.5342e+01
# Epoch:   440, Loss: 2.7391e+01
# Epoch:   441, Loss: 2.6972e+01
# Epoch:   442, Loss: 2.6915e+01
# Epoch:   443, Loss: 2.5489e+01
# Epoch:   444, Loss: 2.6876e+01
# Epoch:   445, Loss: 2.6079e+01
# Epoch:   446, Loss: 2.6893e+01
# Epoch:   447, Loss: 2.7088e+01
# Epoch:   448, Loss: 2.5426e+01
# Epoch:   449, Loss: 2.6282e+01
# Epoch:   450, Loss: 2.6672e+01
# Epoch:   451, Loss: 2.5972e+01
# Epoch:   452, Loss: 2.7129e+01
# Epoch:   453, Loss: 2.6730e+01
# Epoch:   454, Loss: 2.4944e+01
# Epoch:   455, Loss: 2.5516e+01
# Epoch:   456, Loss: 2.6484e+01
# Epoch:   457, Loss: 2.5372e+01
# Epoch:   458, Loss: 2.5526e+01
# Epoch:   459, Loss: 2.6057e+01
# Epoch:   460, Loss: 2.6726e+01
# Epoch:   461, Loss: 2.6535e+01
# Epoch:   462, Loss: 2.5529e+01
# Epoch:   463, Loss: 2.5942e+01
# Epoch:   464, Loss: 2.4328e+01
# Epoch:   465, Loss: 2.5932e+01
# Epoch:   466, Loss: 2.4384e+01
# Epoch:   467, Loss: 2.6136e+01
# Epoch:   468, Loss: 2.5537e+01
# Epoch:   469, Loss: 2.6291e+01
# Epoch:   470, Loss: 2.5960e+01
# Epoch:   471, Loss: 2.5586e+01
# Epoch:   472, Loss: 2.5892e+01
# Epoch:   473, Loss: 2.4828e+01
# Epoch:   474, Loss: 2.5018e+01
# Epoch:   475, Loss: 2.4961e+01
# Epoch:   476, Loss: 2.4806e+01
# Epoch:   477, Loss: 2.4488e+01
# Epoch:   478, Loss: 2.6266e+01
# Epoch:   479, Loss: 2.5162e+01
# Epoch:   480, Loss: 2.5097e+01
# Epoch:   481, Loss: 2.6518e+01
# Epoch:   482, Loss: 2.5384e+01
# Epoch:   483, Loss: 2.4883e+01
# Epoch:   484, Loss: 2.5170e+01
# Epoch:   485, Loss: 2.6107e+01
# Epoch:   486, Loss: 2.4734e+01
# Epoch:   487, Loss: 2.4944e+01
# Epoch:   488, Loss: 2.5387e+01
# Epoch:   489, Loss: 2.4870e+01
# Epoch:   490, Loss: 2.4078e+01
# Epoch:   491, Loss: 2.5287e+01
# Epoch:   492, Loss: 2.4041e+01
# Epoch:   493, Loss: 2.4854e+01
# Epoch:   494, Loss: 2.4341e+01
# Epoch:   495, Loss: 2.4806e+01
# Epoch:   496, Loss: 2.3655e+01
# Epoch:   497, Loss: 2.5363e+01
# Epoch:   498, Loss: 2.4032e+01
# Epoch:   499, Loss: 2.4246e+01

# %%
font_size = 16
fig = plt.figure(figsize=(10, 5))
plt.plot(train_loss_history)
plt.yscale("log")
plt.ylabel("IFWI data residual", fontsize=font_size)
plt.xlabel("Iteration", fontsize=font_size)
# Out:
# Text(0.5, 0, 'Iteration')

# %%
vmodel1, vmodel2, vmodel3 = model.predict()

# %%
font_size = 16
fig = plt.figure(figsize=(15, 10))
gs = fig.add_gridspec(1, 2)
ax = fig.add_subplot(gs[0, 0])
im = ax.imshow(vp_tensor.cpu().squeeze(), extent=[0, nx*dx0/1000, nz*dz0/1000, 0], aspect=1, cmap=color_bar)
cbar = add_colorbar(ax, im, ax.transAxes, width="3%", ctitle='$km/s$')
ax.set_title("True Vp", fontsize=font_size)
ax.set_xlabel("Distance (km)", fontsize=font_size)
ax.set_ylabel("Depth (km)", fontsize=font_size)

ax = fig.add_subplot(gs[0, 1])
im = ax.imshow(vmodel1.squeeze().cpu().detach().squeeze(), \
               extent=[0, nx*dx0/1000, nz*dz0/1000, 0], aspect=1, cmap=color_bar,vmin=vp_tensor.min(), vmax=vp_tensor.max(),)
ax.set_yticks([])
cbar = add_colorbar(ax, im, ax.transAxes, width="3%", ctitle='$km/s$')
ax.set_title("IFWI Vp", fontsize=font_size)
ax.set_xlabel("Distance (km)", fontsize=font_size)
#ax.set_ylabel("Depth (km)", fontsize=font_size)

plt.subplots_adjust(left=0.125,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.2, 
                    hspace=0.4)

# %%
font_size = 16
fig = plt.figure(figsize=(15, 10))
gs = fig.add_gridspec(1, 2)
ax = fig.add_subplot(gs[0, 0])
im = ax.imshow(vs_tensor.cpu().squeeze(), extent=[0, nx*dx0/1000, nz*dz0/1000, 0], aspect=1, cmap=color_bar)
cbar = add_colorbar(ax, im, ax.transAxes, width="3%", ctitle='$km/s$')
ax.set_title("True Vs", fontsize=font_size)
ax.set_xlabel("Distance (km)", fontsize=font_size)
ax.set_ylabel("Depth (km)", fontsize=font_size)

ax = fig.add_subplot(gs[0, 1])
im = ax.imshow(vmodel2.squeeze().cpu().detach().squeeze(), \
               extent=[0, nx*dx0/1000, nz*dz0/1000, 0], aspect=1, cmap=color_bar,vmin=vs_tensor.min(), vmax=vs_tensor.max(),)
ax.set_yticks([])
cbar = add_colorbar(ax, im, ax.transAxes, width="3%", ctitle='$km/s$')
ax.set_title("IFWI Vs", fontsize=font_size)
ax.set_xlabel("Distance (km)", fontsize=font_size)
#ax.set_ylabel("Depth (km)", fontsize=font_size)

plt.subplots_adjust(left=0.125,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.2, 
                    hspace=0.4)

# %%
font_size = 16
fig = plt.figure(figsize=(15, 10))
gs = fig.add_gridspec(1, 2)
ax = fig.add_subplot(gs[0, 0])
im = ax.imshow(rho_tensor.cpu().squeeze(), extent=[0, nx*dx0/1000, nz*dz0/1000, 0], aspect=1, cmap=color_bar)
cbar = add_colorbar(ax, im, ax.transAxes, width="3%", ctitle='$km/s$')
ax.set_title(r"True $\rho$", fontsize=font_size)
ax.set_xlabel("Distance (km)", fontsize=font_size)
ax.set_ylabel("Depth (km)", fontsize=font_size)

ax = fig.add_subplot(gs[0, 1])
im = ax.imshow(vmodel3.squeeze().cpu().detach().squeeze(), \
               extent=[0, nx*dx0/1000, nz*dz0/1000, 0], aspect=1, cmap=color_bar,vmin=rho_tensor.min(), vmax=rho_tensor.max(),)
ax.set_yticks([])
cbar = add_colorbar(ax, im, ax.transAxes, width="3%", ctitle='$km/s$')
ax.set_title(r"IFWI $\rho$", fontsize=font_size)
ax.set_xlabel("Distance (km)", fontsize=font_size)
#ax.set_ylabel("Depth (km)", fontsize=font_size)

plt.subplots_adjust(left=0.125,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.2, 
                    hspace=0.4)

# %%
vmodel1_list = torch.load("./saved_files/vmodel1_list.pt")
vmodel2_list = torch.load("./saved_files/vmodel2_list.pt")
vmodel3_list = torch.load("./saved_files/vmodel3_list.pt")
modle_index_1 = 0
modle_index_2 = 50
modle_index_3 = -1

# %%
font_size = 16
fig = plt.figure(figsize=(30, 10))
gs = fig.add_gridspec(1, 4)
ax = fig.add_subplot(gs[0, 0])
im = ax.imshow(vp_tensor.cpu().squeeze(), extent=[0, nx*dx0/1000, nz*dz0/1000, 0], aspect=1, cmap='bwr')
cbar = add_colorbar(ax, im, ax.transAxes, width="3%", ctitle='$km/s$')
ax.set_title(r"True Vp", fontsize=font_size)
ax.set_xlabel("Distance (km)", fontsize=font_size)
ax.set_ylabel("Depth (km)", fontsize=font_size)

ax = fig.add_subplot(gs[0, 1])
im = ax.imshow(vmodel1_list[modle_index_1], \
               extent=[0, nx*dx0/1000, nz*dz0/1000, 0], aspect=1, cmap='bwr',vmin=vp_tensor.min(), vmax=vp_tensor.max(),)
ax.set_yticks([])
cbar = add_colorbar(ax, im, ax.transAxes, width="3%", ctitle='$km/s$')
ax.set_title(r"IFWI Vp $1^{st}$ iteration", fontsize=font_size)
ax.set_xlabel("Distance (km)", fontsize=font_size)
#ax.set_ylabel("Depth (km)", fontsize=font_size)

ax = fig.add_subplot(gs[0, 2])
im = ax.imshow(vmodel1_list[modle_index_2], \
               extent=[0, nx*dx0/1000, nz*dz0/1000, 0], aspect=1, cmap='bwr',vmin=vp_tensor.min(), vmax=vp_tensor.max(),)
ax.set_yticks([])
cbar = add_colorbar(ax, im, ax.transAxes, width="3%", ctitle='$km/s$')
ax.set_title(r"IFWI Vp $50^{th}$ iteration", fontsize=font_size)
ax.set_xlabel("Distance (km)", fontsize=font_size)
#ax.set_ylabel("Depth (km)", fontsize=font_size)

ax = fig.add_subplot(gs[0, 3])
im = ax.imshow(vmodel1_list[modle_index_3], \
               extent=[0, nx*dx0/1000, nz*dz0/1000, 0], aspect=1, cmap='bwr',vmin=vp_tensor.min(), vmax=vp_tensor.max(),)
ax.set_yticks([])
cbar = add_colorbar(ax, im, ax.transAxes, width="3%", ctitle='$km/s$')
ax.set_title(r"IFWI Vp $500^{th}$ iteration", fontsize=font_size)
ax.set_xlabel("Distance (km)", fontsize=font_size)
#ax.set_ylabel("Depth (km)", fontsize=font_size)

plt.subplots_adjust(left=0.125,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.2, 
                    hspace=0.4)

# %%
font_size = 16
fig = plt.figure(figsize=(30, 10))
gs = fig.add_gridspec(1, 4)
ax = fig.add_subplot(gs[0, 0])
im = ax.imshow(vs_tensor.cpu().squeeze(), extent=[0, nx*dx0/1000, nz*dz0/1000, 0], aspect=1, cmap='bwr')
cbar = add_colorbar(ax, im, ax.transAxes, width="3%", ctitle='$km/s$')
ax.set_title(r"True Vs", fontsize=font_size)
ax.set_xlabel("Distance (km)", fontsize=font_size)
ax.set_ylabel("Depth (km)", fontsize=font_size)

ax = fig.add_subplot(gs[0, 1])
im = ax.imshow(vmodel2_list[modle_index_1], \
               extent=[0, nx*dx0/1000, nz*dz0/1000, 0], aspect=1, cmap='bwr',vmin=vs_tensor.min(), vmax=vs_tensor.max(),)
ax.set_yticks([])
cbar = add_colorbar(ax, im, ax.transAxes, width="3%", ctitle='$km/s$')
ax.set_title(r"IFWI Vs $1^{st}$ iteration", fontsize=font_size)
ax.set_xlabel("Distance (km)", fontsize=font_size)
#ax.set_ylabel("Depth (km)", fontsize=font_size)

ax = fig.add_subplot(gs[0, 2])
im = ax.imshow(vmodel2_list[modle_index_2], \
               extent=[0, nx*dx0/1000, nz*dz0/1000, 0], aspect=1, cmap='bwr',vmin=vs_tensor.min(), vmax=vs_tensor.max(),)
ax.set_yticks([])
cbar = add_colorbar(ax, im, ax.transAxes, width="3%", ctitle='$km/s$')
ax.set_title(r"IFWI Vs $50^{th}$ iteration", fontsize=font_size)
ax.set_xlabel("Distance (km)", fontsize=font_size)
#ax.set_ylabel("Depth (km)", fontsize=font_size)

ax = fig.add_subplot(gs[0, 3])
im = ax.imshow(vmodel2_list[modle_index_3], \
               extent=[0, nx*dx0/1000, nz*dz0/1000, 0], aspect=1, cmap='bwr',vmin=vs_tensor.min(), vmax=vs_tensor.max(),)
ax.set_yticks([])
cbar = add_colorbar(ax, im, ax.transAxes, width="3%", ctitle='$km/s$')
ax.set_title(r"IFWI Vs $500^{th}$ iteration", fontsize=font_size)
ax.set_xlabel("Distance (km)", fontsize=font_size)
#ax.set_ylabel("Depth (km)", fontsize=font_size)

plt.subplots_adjust(left=0.125,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.2, 
                    hspace=0.4)

# %%
font_size = 16
fig = plt.figure(figsize=(30, 10))
gs = fig.add_gridspec(1, 4)
ax = fig.add_subplot(gs[0, 0])
im = ax.imshow(rho_tensor.cpu().squeeze(), extent=[0, nx*dx0/1000, nz*dz0/1000, 0], aspect=1, cmap='bwr')
cbar = add_colorbar(ax, im, ax.transAxes, width="3%", ctitle='$kg/m^{3}$')
ax.set_title(r"True $\rho$", fontsize=font_size)
ax.set_xlabel("Distance (km)", fontsize=font_size)
ax.set_ylabel("Depth (km)", fontsize=font_size)

ax = fig.add_subplot(gs[0, 1])
im = ax.imshow(vmodel3_list[modle_index_1], \
               extent=[0, nx*dx0/1000, nz*dz0/1000, 0], aspect=1, cmap='bwr',vmin=rho_tensor.min(), vmax=rho_tensor.max(),)
ax.set_yticks([])
cbar = add_colorbar(ax, im, ax.transAxes, width="3%", ctitle='$kg/m^{3}$')
ax.set_title(r"IFWI $\rho$ $1^{st}$ iteration", fontsize=font_size)
ax.set_xlabel("Distance (km)", fontsize=font_size)
#ax.set_ylabel("Depth (km)", fontsize=font_size)

ax = fig.add_subplot(gs[0, 2])
im = ax.imshow(vmodel3_list[modle_index_2], \
               extent=[0, nx*dx0/1000, nz*dz0/1000, 0], aspect=1, cmap='bwr',vmin=rho_tensor.min(), vmax=rho_tensor.max(),)
ax.set_yticks([])
cbar = add_colorbar(ax, im, ax.transAxes, width="3%", ctitle='$kg/m^{3}$')
ax.set_title(r"IFWI $\rho$ $50^{th}$ iteration", fontsize=font_size)
ax.set_xlabel("Distance (km)", fontsize=font_size)
#ax.set_ylabel("Depth (km)", fontsize=font_size)

ax = fig.add_subplot(gs[0, 3])
im = ax.imshow(vmodel3_list[modle_index_3], \
               extent=[0, nx*dx0/1000, nz*dz0/1000, 0], aspect=1, cmap='bwr',vmin=rho_tensor.min(), vmax=rho_tensor.max(),)
ax.set_yticks([])
cbar = add_colorbar(ax, im, ax.transAxes, width="3%", ctitle='$kg/m^{3}$')
ax.set_title(r"IFWI $\rho$ $500^{th}$ iteration", fontsize=font_size)
ax.set_xlabel("Distance (km)", fontsize=font_size)
#ax.set_ylabel("Depth (km)", fontsize=font_size)

plt.subplots_adjust(left=0.125,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.2, 
                    hspace=0.4)

# %%
trace_index = 55
vp_true_v_profile = vp_tensor[:,:,trace_index].cpu().detach().squeeze()
vp_IFWI_initi_v_profile = vmodel1_list[0][:,trace_index]
vp_IFWI_final_v_profile = vmodel1_list[-1][:,trace_index]

vs_true_v_profile = vs_tensor[:,:,trace_index].cpu().detach().squeeze()
vs_IFWI_initi_v_profile = vmodel2_list[0][:,trace_index]
vs_IFWI_final_v_profile = vmodel2_list[-1][:,trace_index]

rho_true_v_profile = rho_tensor[:,:,trace_index].cpu().detach().squeeze()
rho_IFWI_initi_v_profile = vmodel3_list[0][:,trace_index]
rho_IFWI_final_v_profile = vmodel3_list[-1][:,trace_index]


depth = np.arange(0, nz, 1, dtype=np.int32)*dz0 # receiver x-coordinate

font_size = 12
fig = plt.figure(figsize=(30, 4))
gs = fig.add_gridspec(1, 3)
ax = fig.add_subplot(gs[0, 0])
plt.plot(depth, vp_true_v_profile, linewidth='2', label='True Vp')
plt.plot(depth, vp_IFWI_initi_v_profile, linewidth='2', label='IFWI Vp $1^{st}$ iteration')
plt.plot(depth, vp_IFWI_final_v_profile, linewidth='2', label='IFWI Vp $500^{th}$ iteration')
plt.legend(fontsize=font_size)
plt.ylabel("Vp  (m/s)", fontsize=font_size)
plt.xlabel("Depth (m)", fontsize=font_size)

ax = fig.add_subplot(gs[0, 1])
plt.plot(depth, vs_true_v_profile, linewidth='2', label='True Vs')
plt.plot(depth, vs_IFWI_initi_v_profile, linewidth='2', label='IFWI Vs $1^{st}$ iteration')
plt.plot(depth, vs_IFWI_final_v_profile, linewidth='2', label='IFWI Vs $500^{th}$ iteration')
plt.legend(fontsize=font_size)
plt.ylabel("Vs  (m/s)", fontsize=font_size)
plt.xlabel("Depth (m)", fontsize=font_size)

ax = fig.add_subplot(gs[0, 2])
plt.plot(depth, rho_true_v_profile, linewidth='2', label=r'True $\rho$')
plt.plot(depth, rho_IFWI_initi_v_profile, linewidth='2', label=r'IFWI $\rho$ $1^{st}$ iteration')
plt.plot(depth, rho_IFWI_final_v_profile, linewidth='2', label=r'IFWI $\rho$ $500^{th}$ iteration')
plt.legend(fontsize=font_size)
plt.ylabel(r"$\rho$  ($kg/m^{3}$)", fontsize=font_size)
plt.xlabel("Depth (m)", fontsize=font_size)
# Out:
# Text(0.5, 0, 'Depth (m)')
